# %%
#siempre transformar una imagen a float32 para poder operar con ella y retornar un entero
import cv2
import numpy as np
from matplotlib import pyplot as plt

imagen = cv2.imread('arbol.jpg',1)
imagen = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)
imagen.astype(np.float32)
imagen.astype(np.uint8)
imagen = np.clip(imagen, 0, 255)
b,g,r = cv2.split(imagen)
imagen_final = cv2.merge([b,g,r])

H = cv2.getGaussianKernel(11,3)*cv2.getGaussianKernel(11,3)
claves, valor = np.unique(imagen,return_counts=True)
diccionario = dict(zip(claves,valor))
